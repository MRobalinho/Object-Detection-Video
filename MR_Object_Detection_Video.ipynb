# %% [markdown]
# # Object Detection Video
#
# ### Documentation:
# https://imageai.readthedocs.io/en/latest/
# https://imageai.readthedocs.io/en/latest/video/index.html
# https://towardsdatascience.com/object-detection-with-10-lines-of-code-d6cb4d86f606
# https://github.com/OlafenwaMoses/ImageAI/blob/master/imageai/Detection/VIDEO.md
#
# MRobalinho - 05-11-2018

# %% [markdown]
# -------------------------------------------------------
# #### In order to Install ImageAI see this page:
#
# https://imageai.readthedocs.io/en/latest/
#
# <br/>Installing ImageAI
# <br/>ImageAI requires that you have Python 3.5.1 or higher installed as well as some other Python libraries and frameworks. Before you install ImageAI, you must install the following dependencies.
# <br/>
# <br/>Download and install:
# <br/>Python 3.5.1 or higher, Download Python here: https://www.python.org/downloads/
# <br/>pip3 , Download PyPi here: https://pypi.org/project/pip/
# <br/>
# <br/>Use Command line CMD.exe as admnistrator
# <br/>
# <br/>Tensorflow 1.4.0 or higher  > pip3 install --upgrade tensorflow
# <br/>Numpy 1.13.1 or higher     	> pip3 install numpy
# <br/>SciPy .19.1 or higher		> pip3 install scipy
# <br/>OpenCV						> pip3 install opencv-python
# <br/>Pillow						> pip3 install pillow
# <br/>Matplotlib					> pip3 install matplotlib
# <br/>h5py						> pip3 install h5py
# <br/>Keras						> pip3 install keras
# <br/>Install ImageAI  			> pip3 install https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl
#
# -------------------------

# %%
# Import packages
from imageai.Detection import VideoObjectDetection
import os
# Out:
# Using TensorFlow backend.

# %% [markdown]
# VideoObjectDetection class provides you function to detect objects in videos and live-feed from device cameras and IP cameras, using pre-trained models that was trained on the COCO dataset. The models supported are RetinaNet, YOLOv3 and TinyYOLOv3. This means you can detect and recognize 80 different kind of common everyday objects in any video. To get started, download any of the pre-trained model that you want to use via the links below.
#
# <br/>Download RetinaNet Model - resnet50_coco_best_v2.0.1.h5
# <br/>https://github.com/OlafenwaMoses/ImageAI/releases/tag/1.0/
# <br/>Download YOLOv3 Model - yolo.h5
# <br/>https://github.com/OlafenwaMoses/ImageAI/releases/tag/1.0/
# <br/>Download TinyYOLOv3 Model - yolo-tiny.h5
# <br/>https://github.com/OlafenwaMoses/ImageAI/releases/tag/1.0/

# %% [markdown]
# To obtain the video analysis, we need to do is specify a function, state the corresponding parameters it will be receiving and parse the function name into the per_frame_function, per_second_function, per_minute_function and video_complete_function parameters in the detection function.

# %% [markdown]
# For any function we parse into the <b> per_frame_function</b>, the function will be executed after every single video frame is processed and he following will be parsed into it:
# >> Frame Index : This is the position number of the frame inside the video (e.g 1 for first frame and 20 for twentieth frame).
#
# >> Output Array : This is an array of dictionaries. Each dictionary corresponds to each detected object in the image and it contains the "name", "percentage_probabaility" and "box_points"(x1,y1,x2,y2) values of the object.
#
# >> Output Count : This is a dictionary that has the name of each unique object detected as its keys and the number of instances of the objects detected as the values.

# %% [markdown]
# In the above result, the video was processed and saved in 10 frames per second (FPS). For any function you parse into the <b>per_second_function</b>, the function will be executed after every single second of the video that is processed and he following will be parsed into it:
# >> Second Index : This is the position number of the second inside the video (e.g 1 for first second and 20 for twentieth second).
#
# >> Output Array : This is an array of arrays, with each contained array and its position (array index + 1) corresponding to the equivalent frame in the last second of the video. Each contained array contains dictionaries. Each dictionary corresponds to each detected object in the image and it contains the "name", "percentage_probabaility" and "box_points"(x1,y1,x2,y2) values of the object.
#
# >> Count arrays : This is an array of dictionaries. Each dictionary and its position (array index + 1) corresponds to the equivalent frame in the last second of he video. Each dictionary has the name of each unique object detected as its keys and the number of instances of the objects detected as the values.
#
# >> Average Output Count : This is a dictionary that has the name of each unique object detected in the last second as its keys and the average number of instances of the objects detected across the number of frames as the values.

# %%
def forFrame(frame_number, output_array, output_count, detected_copy):
    print("FOR FRAME " , frame_number)
#    print("Output for each object : ", output_array)
    print("Output count for unique objects : ", output_count)
    print("------------END OF A FRAME --------------")

def forSeconds(second_number, output_arrays, count_arrays, average_output_count, detected_copy):
    print("SECOND : ", second_number)
#    print("Array for the outputs of each frame ", output_arrays)
    print("Array for output count for unique objects in each frame : ", count_arrays)
    print("Output average count for unique objects in the last second: ", average_output_count)
    print("------------END OF A SECOND --------------")

def forMinute(minute_number, output_arrays, count_arrays, average_output_count, detected_copy):
    print("MINUTE : ", minute_number)
#    print("Array for the outputs of each frame ", output_arrays)
    print("Array for output count for unique objects in each frame : ", count_arrays)
    print("Output average count for unique objects in the last minute: ", average_output_count)
    print("------------END OF A MINUTE --------------")

# %%
# Path to execute
yolo_path = 'TinyYOLOv3_Model/'
video_path = 'Video/'
execution_path = os.getcwd()
execution_path
# Out:
# 'C:\\Users\\Lenovo\\ML\\Object-Detection-Video'

# %%
video_path
# Out:
# 'Video/'

# %%
# Video to Use
use_video = "traffic.mp4"

# %%
# Model to Use
use_model = "yolo-tiny.h5"

analisys_video = "detected_" + use_video

detector = VideoObjectDetection()

# Iniciate model
#detector.setModelTypeAsYOLOv3()      # To YOLOv3 model
#detector.setModelTypeAsRetinaNet()   # To Retinanet model
detector.setModelTypeAsTinyYOLOv3()   # To TinyYOLOv3 model

detector.setModelPath( os.path.join(yolo_path , use_model))
detector.loadModel()

vid_path = detector.detectObjectsFromVideo(input_file_path=os.path.join( video_path, use_video),
                                           output_file_path=os.path.join(video_path, analisys_video),
                                           frames_per_second=20,
                                 #          per_second_function = forSeconds,
                                           per_frame_function = forFrame,
                                 #          per_minute_function= forMinute,
                                           minimum_percentage_probability=30,
                                           log_progress=True,
                                           return_detected_frame=True)
                                           
 
print(vid_path)
# Out:
# Processing Frame :  1
# FOR FRAME  1
# Output count for unique objects :  {'bus': 3, 'car': 13, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  2
# FOR FRAME  2
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 13, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  3
# FOR FRAME  3
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 14, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  4
# FOR FRAME  4
# Output count for unique objects :  {'cell phone': 1, 'bus': 3, 'motorcycle': 1, 'car': 14, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  5
# FOR FRAME  5
# Output count for unique objects :  {'bus': 3, 'car': 14, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  6
# FOR FRAME  6
# Output count for unique objects :  {'bus': 3, 'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  7
# FOR FRAME  7
# Output count for unique objects :  {'bus': 3, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  8
# FOR FRAME  8
# Output count for unique objects :  {'bus': 3, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  9
# FOR FRAME  9
# Output count for unique objects :  {'bus': 3, 'car': 11, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  10
# FOR FRAME  10
# Output count for unique objects :  {'bus': 3, 'car': 13, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  11
# FOR FRAME  11
# Output count for unique objects :  {'bus': 3, 'car': 13, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  12
# FOR FRAME  12
# Output count for unique objects :  {'bus': 3, 'car': 13, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  13
# FOR FRAME  13
# Output count for unique objects :  {'bus': 3, 'car': 12, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  14
# FOR FRAME  14
# Output count for unique objects :  {'bus': 3, 'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  15
# FOR FRAME  15
# Output count for unique objects :  {'bus': 3, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  16
# FOR FRAME  16
# Output count for unique objects :  {'bus': 3, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  17
# FOR FRAME  17
# Output count for unique objects :  {'bus': 3, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  18
# FOR FRAME  18
# Output count for unique objects :  {'bus': 3, 'car': 13, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  19
# FOR FRAME  19
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 13, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  20
# FOR FRAME  20
# Output count for unique objects :  {'bus': 3, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  21
# FOR FRAME  21
# Output count for unique objects :  {'bus': 3, 'car': 13, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  22
# FOR FRAME  22
# Output count for unique objects :  {'bus': 2, 'car': 14, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  23
# FOR FRAME  23
# Output count for unique objects :  {'bus': 2, 'car': 12, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  24
# FOR FRAME  24
# Output count for unique objects :  {'bus': 2, 'car': 9, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  25
# FOR FRAME  25
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  26
# FOR FRAME  26
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  27
# FOR FRAME  27
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 7, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  28
# FOR FRAME  28
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  29
# FOR FRAME  29
# Output count for unique objects :  {'bus': 3, 'car': 10, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  30
# FOR FRAME  30
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 8, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  31
# FOR FRAME  31
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 8, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  32
# FOR FRAME  32
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  33
# FOR FRAME  33
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 7, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  34
# FOR FRAME  34
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  35
# FOR FRAME  35
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 9, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  36
# FOR FRAME  36
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 7, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  37
# FOR FRAME  37
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 7, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  38
# FOR FRAME  38
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'car': 9, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  39
# FOR FRAME  39
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 8, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  40
# FOR FRAME  40
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  41
# FOR FRAME  41
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  42
# FOR FRAME  42
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 6, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  43
# FOR FRAME  43
# Output count for unique objects :  {'bus': 2, 'car': 13, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  44
# FOR FRAME  44
# Output count for unique objects :  {'bus': 3, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  45
# FOR FRAME  45
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 14, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  46
# FOR FRAME  46
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  47
# FOR FRAME  47
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 12, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  48
# FOR FRAME  48
# Output count for unique objects :  {'bus': 2, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  49
# FOR FRAME  49
# Output count for unique objects :  {'bus': 2, 'car': 13, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  50
# FOR FRAME  50
# Output count for unique objects :  {'bus': 2, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  51
# FOR FRAME  51
# Output count for unique objects :  {'bus': 2, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  52
# FOR FRAME  52
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  53
# FOR FRAME  53
# Output count for unique objects :  {'bus': 3, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  54
# FOR FRAME  54
# Output count for unique objects :  {'bus': 3, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  55
# FOR FRAME  55
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  56
# FOR FRAME  56
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  57
# FOR FRAME  57
# Output count for unique objects :  {'bus': 3, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  58
# FOR FRAME  58
# Output count for unique objects :  {'bus': 3, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  59
# FOR FRAME  59
# Output count for unique objects :  {'bus': 3, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  60
# FOR FRAME  60
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 11, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  61
# FOR FRAME  61
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 8, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  62
# FOR FRAME  62
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  63
# FOR FRAME  63
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  64
# FOR FRAME  64
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 11, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  65
# FOR FRAME  65
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 13, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  66
# FOR FRAME  66
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 13, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  67
# FOR FRAME  67
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 10, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  68
# FOR FRAME  68
# Output count for unique objects :  {'truck': 2, 'bus': 2, 'car': 9, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  69
# FOR FRAME  69
# Output count for unique objects :  {'bus': 2, 'car': 9, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  70
# FOR FRAME  70
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  71
# FOR FRAME  71
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  72
# FOR FRAME  72
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 9, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  73
# FOR FRAME  73
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  74
# FOR FRAME  74
# Output count for unique objects :  {'bus': 3, 'car': 9, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  75
# FOR FRAME  75
# Output count for unique objects :  {'bus': 2, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  76
# FOR FRAME  76
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  77
# FOR FRAME  77
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  78
# FOR FRAME  78
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  79
# FOR FRAME  79
# Output count for unique objects :  {'bus': 2, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  80
# FOR FRAME  80
# Output count for unique objects :  {'bus': 2, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  81
# FOR FRAME  81
# Output count for unique objects :  {'bus': 2, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  82
# FOR FRAME  82
# Output count for unique objects :  {'bus': 4, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  83
# FOR FRAME  83
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  84
# FOR FRAME  84
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  85
# FOR FRAME  85
# Output count for unique objects :  {'bus': 2, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  86
# FOR FRAME  86
# Output count for unique objects :  {'bus': 2, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  87
# FOR FRAME  87
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 7, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  88
# FOR FRAME  88
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 8, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  89
# FOR FRAME  89
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 7, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  90
# FOR FRAME  90
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 8, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  91
# FOR FRAME  91
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 7, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  92
# FOR FRAME  92
# Output count for unique objects :  {'bus': 2, 'motorcycle': 2, 'car': 6, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  93
# FOR FRAME  93
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 7, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  94
# FOR FRAME  94
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 5, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  95
# FOR FRAME  95
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  96
# FOR FRAME  96
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 8, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  97
# FOR FRAME  97
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 8, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  98
# FOR FRAME  98
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 5, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  99
# FOR FRAME  99
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 4, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  100
# FOR FRAME  100
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 4, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  101
# FOR FRAME  101
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 5, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  102
# FOR FRAME  102
# Output count for unique objects :  {'bus': 2, 'motorcycle': 2, 'car': 6, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  103
# FOR FRAME  103
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 4, 'bicycle': 2, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  104
# FOR FRAME  104
# Output count for unique objects :  {'truck': 1, 'bus': 5, 'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  105
# FOR FRAME  105
# Output count for unique objects :  {'truck': 1, 'bus': 5, 'motorcycle': 1, 'car': 3, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  106
# FOR FRAME  106
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  107
# FOR FRAME  107
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  108
# FOR FRAME  108
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  109
# FOR FRAME  109
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 5, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  110
# FOR FRAME  110
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 5, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  111
# FOR FRAME  111
# Output count for unique objects :  {'bus': 5, 'car': 7, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  112
# FOR FRAME  112
# Output count for unique objects :  {'bus': 4, 'car': 6, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  113
# FOR FRAME  113
# Output count for unique objects :  {'bus': 5, 'car': 10, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  114
# FOR FRAME  114
# Output count for unique objects :  {'bus': 4, 'car': 8, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  115
# FOR FRAME  115
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 7, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  116
# FOR FRAME  116
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 8, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  117
# FOR FRAME  117
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  118
# FOR FRAME  118
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 7, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  119
# FOR FRAME  119
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  120
# FOR FRAME  120
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 9, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  121
# FOR FRAME  121
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  122
# FOR FRAME  122
# Output count for unique objects :  {'bus': 3, 'car': 11, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  123
# FOR FRAME  123
# Output count for unique objects :  {'bus': 3, 'car': 6, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  124
# FOR FRAME  124
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  125
# FOR FRAME  125
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  126
# FOR FRAME  126
# Output count for unique objects :  {'bus': 4, 'motorcycle': 1, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  127
# FOR FRAME  127
# Output count for unique objects :  {'bus': 3, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  128
# FOR FRAME  128
# Output count for unique objects :  {'bus': 2, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  129
# FOR FRAME  129
# Output count for unique objects :  {'bus': 2, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  130
# FOR FRAME  130
# Output count for unique objects :  {'bus': 2, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  131
# FOR FRAME  131
# Output count for unique objects :  {'bus': 3, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  132
# FOR FRAME  132
# Output count for unique objects :  {'bus': 3, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  133
# FOR FRAME  133
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  134
# FOR FRAME  134
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  135
# FOR FRAME  135
# Output count for unique objects :  {'bus': 2, 'car': 9, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  136
# FOR FRAME  136
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 8, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  137
# FOR FRAME  137
# Output count for unique objects :  {'bus': 2, 'car': 6, 'bicycle': 1, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  138
# FOR FRAME  138
# Output count for unique objects :  {'bus': 3, 'car': 7, 'bicycle': 1, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  139
# FOR FRAME  139
# Output count for unique objects :  {'bus': 2, 'car': 9, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  140
# FOR FRAME  140
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 9, 'bicycle': 1, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  141
# FOR FRAME  141
# Output count for unique objects :  {'bus': 2, 'car': 6, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  142
# FOR FRAME  142
# Output count for unique objects :  {'bus': 2, 'car': 7, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  143
# FOR FRAME  143
# Output count for unique objects :  {'bus': 3, 'car': 9, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  144
# FOR FRAME  144
# Output count for unique objects :  {'bus': 2, 'car': 8, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  145
# FOR FRAME  145
# Output count for unique objects :  {'bus': 2, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  146
# FOR FRAME  146
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  147
# FOR FRAME  147
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 6, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  148
# FOR FRAME  148
# Output count for unique objects :  {'bus': 2, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  149
# FOR FRAME  149
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 9, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  150
# FOR FRAME  150
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'motorcycle': 1, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  151
# FOR FRAME  151
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 8, 'bicycle': 1, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  152
# FOR FRAME  152
# Output count for unique objects :  {'bus': 2, 'car': 9, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  153
# FOR FRAME  153
# Output count for unique objects :  {'bus': 3, 'car': 8, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  154
# FOR FRAME  154
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 7, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  155
# FOR FRAME  155
# Output count for unique objects :  {'bus': 2, 'car': 8, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  156
# FOR FRAME  156
# Output count for unique objects :  {'bus': 2, 'car': 7, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  157
# FOR FRAME  157
# Output count for unique objects :  {'bus': 2, 'car': 7, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  158
# FOR FRAME  158
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 5, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  159
# FOR FRAME  159
# Output count for unique objects :  {'suitcase': 1, 'truck': 1, 'bus': 2, 'car': 5, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  160
# FOR FRAME  160
# Output count for unique objects :  {'suitcase': 1, 'truck': 1, 'bus': 2, 'car': 7, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  161
# FOR FRAME  161
# Output count for unique objects :  {'suitcase': 1, 'truck': 1, 'bus': 2, 'car': 8, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  162
# FOR FRAME  162
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'car': 7, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  163
# FOR FRAME  163
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 6, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  164
# FOR FRAME  164
# Output count for unique objects :  {'bus': 4, 'car': 7, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  165
# FOR FRAME  165
# Output count for unique objects :  {'bus': 4, 'car': 7, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  166
# FOR FRAME  166
# Output count for unique objects :  {'bus': 5, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  167
# FOR FRAME  167
# Output count for unique objects :  {'bus': 4, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  168
# FOR FRAME  168
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  169
# FOR FRAME  169
# Output count for unique objects :  {'suitcase': 1, 'bus': 2, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  170
# FOR FRAME  170
# Output count for unique objects :  {'suitcase': 1, 'bus': 3, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  171
# FOR FRAME  171
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  172
# FOR FRAME  172
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  173
# FOR FRAME  173
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  174
# FOR FRAME  174
# Output count for unique objects :  {'suitcase': 1, 'bus': 2, 'car': 9, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  175
# FOR FRAME  175
# Output count for unique objects :  {'bus': 3, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  176
# FOR FRAME  176
# Output count for unique objects :  {'bus': 3, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  177
# FOR FRAME  177
# Output count for unique objects :  {'bus': 4, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  178
# FOR FRAME  178
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  179
# FOR FRAME  179
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  180
# FOR FRAME  180
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  181
# FOR FRAME  181
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  182
# FOR FRAME  182
# Output count for unique objects :  {'bus': 3, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  183
# FOR FRAME  183
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 8, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  184
# FOR FRAME  184
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  185
# FOR FRAME  185
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  186
# FOR FRAME  186
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  187
# FOR FRAME  187
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  188
# FOR FRAME  188
# Output count for unique objects :  {'bus': 3, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  189
# FOR FRAME  189
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  190
# FOR FRAME  190
# Output count for unique objects :  {'bus': 3, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  191
# FOR FRAME  191
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  192
# FOR FRAME  192
# Output count for unique objects :  {'bus': 4, 'car': 4, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  193
# FOR FRAME  193
# Output count for unique objects :  {'bus': 4, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  194
# FOR FRAME  194
# Output count for unique objects :  {'bus': 4, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  195
# FOR FRAME  195
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  196
# FOR FRAME  196
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  197
# FOR FRAME  197
# Output count for unique objects :  {'chair': 1, 'truck': 1, 'bus': 3, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  198
# FOR FRAME  198
# Output count for unique objects :  {'chair': 1, 'bus': 3, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  199
# FOR FRAME  199
# Output count for unique objects :  {'bus': 4, 'car': 4, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  200
# FOR FRAME  200
# Output count for unique objects :  {'bus': 3, 'car': 4, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  201
# FOR FRAME  201
# Output count for unique objects :  {'chair': 1, 'bus': 3, 'car': 3, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  202
# FOR FRAME  202
# Output count for unique objects :  {'bus': 3, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  203
# FOR FRAME  203
# Output count for unique objects :  {'chair': 1, 'bus': 4, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  204
# FOR FRAME  204
# Output count for unique objects :  {'bus': 3, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  205
# FOR FRAME  205
# Output count for unique objects :  {'bus': 4, 'car': 3, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  206
# FOR FRAME  206
# Output count for unique objects :  {'truck': 1, 'bus': 5, 'car': 3, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  207
# FOR FRAME  207
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'car': 4, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  208
# FOR FRAME  208
# Output count for unique objects :  {'truck': 1, 'bus': 4, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  209
# FOR FRAME  209
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  210
# FOR FRAME  210
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  211
# FOR FRAME  211
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  212
# FOR FRAME  212
# Output count for unique objects :  {'bus': 2, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  213
# FOR FRAME  213
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  214
# FOR FRAME  214
# Output count for unique objects :  {'truck': 2, 'bus': 3, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  215
# FOR FRAME  215
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  216
# FOR FRAME  216
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  217
# FOR FRAME  217
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  218
# FOR FRAME  218
# Output count for unique objects :  {'bus': 2, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  219
# FOR FRAME  219
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  220
# FOR FRAME  220
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  221
# FOR FRAME  221
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  222
# FOR FRAME  222
# Output count for unique objects :  {'bus': 2, 'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  223
# FOR FRAME  223
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  224
# FOR FRAME  224
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 6, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  225
# FOR FRAME  225
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  226
# FOR FRAME  226
# Output count for unique objects :  {'bus': 2, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  227
# FOR FRAME  227
# Output count for unique objects :  {'bus': 2, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  228
# FOR FRAME  228
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  229
# FOR FRAME  229
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  230
# FOR FRAME  230
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  231
# FOR FRAME  231
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  232
# FOR FRAME  232
# Output count for unique objects :  {'truck': 2, 'bus': 2, 'motorcycle': 1, 'car': 7, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  233
# FOR FRAME  233
# Output count for unique objects :  {'truck': 2, 'bus': 2, 'motorcycle': 1, 'car': 9, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  234
# FOR FRAME  234
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 9, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  235
# FOR FRAME  235
# Output count for unique objects :  {'truck': 2, 'bus': 2, 'car': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  236
# FOR FRAME  236
# Output count for unique objects :  {'bus': 2, 'car': 10, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  237
# FOR FRAME  237
# Output count for unique objects :  {'bus': 2, 'car': 10}
# ------------END OF A FRAME --------------
# Processing Frame :  238
# FOR FRAME  238
# Output count for unique objects :  {'bus': 2, 'car': 9}
# ------------END OF A FRAME --------------
# Processing Frame :  239
# FOR FRAME  239
# Output count for unique objects :  {'bus': 2, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  240
# FOR FRAME  240
# Output count for unique objects :  {'bus': 2, 'car': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  241
# FOR FRAME  241
# Output count for unique objects :  {'bus': 2, 'car': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  242
# FOR FRAME  242
# Output count for unique objects :  {'bus': 2, 'car': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  243
# FOR FRAME  243
# Output count for unique objects :  {'bus': 2, 'car': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  244
# FOR FRAME  244
# Output count for unique objects :  {'bus': 2, 'car': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  245
# FOR FRAME  245
# Output count for unique objects :  {'bus': 2, 'car': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  246
# FOR FRAME  246
# Output count for unique objects :  {'bus': 2, 'car': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  247
# FOR FRAME  247
# Output count for unique objects :  {'bus': 2, 'car': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  248
# FOR FRAME  248
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 6, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  249
# FOR FRAME  249
# Output count for unique objects :  {'bus': 2, 'car': 8, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  250
# FOR FRAME  250
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  251
# FOR FRAME  251
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  252
# FOR FRAME  252
# Output count for unique objects :  {'bus': 3, 'car': 5, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  253
# FOR FRAME  253
# Output count for unique objects :  {'bus': 3, 'car': 6, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  254
# FOR FRAME  254
# Output count for unique objects :  {'bus': 3, 'car': 7, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  255
# FOR FRAME  255
# Output count for unique objects :  {'bus': 2, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  256
# FOR FRAME  256
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  257
# FOR FRAME  257
# Output count for unique objects :  {'bus': 2, 'car': 7, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  258
# FOR FRAME  258
# Output count for unique objects :  {'bus': 2, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  259
# FOR FRAME  259
# Output count for unique objects :  {'bus': 2, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  260
# FOR FRAME  260
# Output count for unique objects :  {'bus': 2, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  261
# FOR FRAME  261
# Output count for unique objects :  {'bus': 2, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  262
# FOR FRAME  262
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  263
# FOR FRAME  263
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  264
# FOR FRAME  264
# Output count for unique objects :  {'bus': 2, 'car': 9, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  265
# FOR FRAME  265
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  266
# FOR FRAME  266
# Output count for unique objects :  {'bus': 2, 'car': 7, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  267
# FOR FRAME  267
# Output count for unique objects :  {'bus': 2, 'car': 8, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  268
# FOR FRAME  268
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  269
# FOR FRAME  269
# Output count for unique objects :  {'bus': 2, 'motorcycle': 1, 'car': 7, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  270
# FOR FRAME  270
# Output count for unique objects :  {'bus': 3, 'motorcycle': 1, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  271
# FOR FRAME  271
# Output count for unique objects :  {'bus': 3, 'car': 6, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  272
# FOR FRAME  272
# Output count for unique objects :  {'bus': 2, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  273
# FOR FRAME  273
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  274
# FOR FRAME  274
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  275
# FOR FRAME  275
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  276
# FOR FRAME  276
# Output count for unique objects :  {'chair': 1, 'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  277
# FOR FRAME  277
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  278
# FOR FRAME  278
# Output count for unique objects :  {'chair': 1, 'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  279
# FOR FRAME  279
# Output count for unique objects :  {'chair': 1, 'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  280
# FOR FRAME  280
# Output count for unique objects :  {'chair': 1, 'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 5, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  281
# FOR FRAME  281
# Output count for unique objects :  {'chair': 1, 'bus': 2, 'motorcycle': 1, 'car': 5, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  282
# FOR FRAME  282
# Output count for unique objects :  {'chair': 1, 'truck': 1, 'bus': 2, 'motorcycle': 1, 'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  283
# FOR FRAME  283
# Output count for unique objects :  {'chair': 1, 'truck': 1, 'bus': 2, 'car': 6, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  284
# FOR FRAME  284
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  285
# FOR FRAME  285
# Output count for unique objects :  {'chair': 1, 'bus': 1, 'motorcycle': 1, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  286
# FOR FRAME  286
# Output count for unique objects :  {'bus': 1, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  287
# FOR FRAME  287
# Output count for unique objects :  {'bus': 1, 'car': 6, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  288
# FOR FRAME  288
# Output count for unique objects :  {'bus': 1, 'car': 8, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  289
# FOR FRAME  289
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 8, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  290
# FOR FRAME  290
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  291
# FOR FRAME  291
# Output count for unique objects :  {'bus': 1, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  292
# FOR FRAME  292
# Output count for unique objects :  {'truck': 2, 'bus': 1, 'motorcycle': 1, 'car': 9, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  293
# FOR FRAME  293
# Output count for unique objects :  {'truck': 2, 'bus': 1, 'motorcycle': 1, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  294
# FOR FRAME  294
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'motorcycle': 2, 'car': 11, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  295
# FOR FRAME  295
# Output count for unique objects :  {'truck': 1, 'bus': 3, 'motorcycle': 1, 'car': 8, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  296
# FOR FRAME  296
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'motorcycle': 2, 'car': 8, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  297
# FOR FRAME  297
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'motorcycle': 2, 'car': 9, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  298
# FOR FRAME  298
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'motorcycle': 2, 'car': 9, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  299
# FOR FRAME  299
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'motorcycle': 1, 'car': 9, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  300
# FOR FRAME  300
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 8, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  301
# FOR FRAME  301
# Output count for unique objects :  {'bus': 3, 'car': 9, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  302
# FOR FRAME  302
# ...
# ------------END OF A FRAME --------------
# Processing Frame :  501
# FOR FRAME  501
# Output count for unique objects :  {'motorcycle': 2, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  502
# FOR FRAME  502
# Output count for unique objects :  {'motorcycle': 2, 'car': 14, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  503
# FOR FRAME  503
# Output count for unique objects :  {'motorcycle': 2, 'car': 14, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  504
# FOR FRAME  504
# Output count for unique objects :  {'motorcycle': 3, 'car': 11, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  505
# FOR FRAME  505
# Output count for unique objects :  {'motorcycle': 1, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  506
# FOR FRAME  506
# Output count for unique objects :  {'motorcycle': 1, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  507
# FOR FRAME  507
# Output count for unique objects :  {'motorcycle': 2, 'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  508
# FOR FRAME  508
# Output count for unique objects :  {'motorcycle': 3, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  509
# FOR FRAME  509
# Output count for unique objects :  {'motorcycle': 4, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  510
# FOR FRAME  510
# Output count for unique objects :  {'motorcycle': 4, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  511
# FOR FRAME  511
# Output count for unique objects :  {'motorcycle': 4, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  512
# FOR FRAME  512
# Output count for unique objects :  {'motorcycle': 2, 'car': 9, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  513
# FOR FRAME  513
# Output count for unique objects :  {'motorcycle': 4, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  514
# FOR FRAME  514
# Output count for unique objects :  {'motorcycle': 4, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  515
# FOR FRAME  515
# Output count for unique objects :  {'motorcycle': 4, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  516
# FOR FRAME  516
# Output count for unique objects :  {'motorcycle': 3, 'car': 11, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  517
# FOR FRAME  517
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 14, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  518
# FOR FRAME  518
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  519
# FOR FRAME  519
# Output count for unique objects :  {'bus': 1, 'motorcycle': 2, 'car': 13, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  520
# FOR FRAME  520
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  521
# FOR FRAME  521
# Output count for unique objects :  {'bus': 1, 'car': 11, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  522
# FOR FRAME  522
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 11, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  523
# FOR FRAME  523
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  524
# FOR FRAME  524
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 12, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  525
# FOR FRAME  525
# Output count for unique objects :  {'motorcycle': 2, 'car': 14, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  526
# FOR FRAME  526
# Output count for unique objects :  {'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  527
# FOR FRAME  527
# Output count for unique objects :  {'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  528
# FOR FRAME  528
# Output count for unique objects :  {'motorcycle': 1, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  529
# FOR FRAME  529
# Output count for unique objects :  {'car': 13, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  530
# FOR FRAME  530
# Output count for unique objects :  {'motorcycle': 1, 'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  531
# FOR FRAME  531
# Output count for unique objects :  {'motorcycle': 2, 'car': 13, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  532
# FOR FRAME  532
# Output count for unique objects :  {'motorcycle': 1, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  533
# FOR FRAME  533
# Output count for unique objects :  {'motorcycle': 1, 'car': 13, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  534
# FOR FRAME  534
# Output count for unique objects :  {'motorcycle': 2, 'car': 13, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  535
# FOR FRAME  535
# Output count for unique objects :  {'motorcycle': 1, 'car': 11, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  536
# FOR FRAME  536
# Output count for unique objects :  {'motorcycle': 2, 'car': 8, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  537
# FOR FRAME  537
# Output count for unique objects :  {'motorcycle': 5, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  538
# FOR FRAME  538
# Output count for unique objects :  {'motorcycle': 4, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  539
# FOR FRAME  539
# Output count for unique objects :  {'motorcycle': 4, 'car': 12, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  540
# FOR FRAME  540
# Output count for unique objects :  {'motorcycle': 3, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  541
# FOR FRAME  541
# Output count for unique objects :  {'motorcycle': 3, 'car': 11, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  542
# FOR FRAME  542
# Output count for unique objects :  {'motorcycle': 4, 'car': 14, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  543
# FOR FRAME  543
# Output count for unique objects :  {'motorcycle': 4, 'car': 13, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  544
# FOR FRAME  544
# Output count for unique objects :  {'bus': 1, 'motorcycle': 3, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  545
# FOR FRAME  545
# Output count for unique objects :  {'bus': 1, 'motorcycle': 2, 'car': 11, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  546
# FOR FRAME  546
# Output count for unique objects :  {'motorcycle': 3, 'car': 11, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  547
# FOR FRAME  547
# Output count for unique objects :  {'motorcycle': 3, 'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  548
# FOR FRAME  548
# Output count for unique objects :  {'motorcycle': 6, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  549
# FOR FRAME  549
# Output count for unique objects :  {'motorcycle': 6, 'car': 11, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  550
# FOR FRAME  550
# Output count for unique objects :  {'truck': 1, 'motorcycle': 5, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  551
# FOR FRAME  551
# Output count for unique objects :  {'truck': 1, 'motorcycle': 5, 'car': 12, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  552
# FOR FRAME  552
# Output count for unique objects :  {'motorcycle': 6, 'car': 15, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  553
# FOR FRAME  553
# Output count for unique objects :  {'motorcycle': 6, 'car': 16, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  554
# FOR FRAME  554
# Output count for unique objects :  {'motorcycle': 5, 'car': 12, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  555
# FOR FRAME  555
# Output count for unique objects :  {'motorcycle': 3, 'car': 12, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  556
# FOR FRAME  556
# Output count for unique objects :  {'motorcycle': 4, 'car': 14, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  557
# FOR FRAME  557
# Output count for unique objects :  {'motorcycle': 5, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  558
# FOR FRAME  558
# Output count for unique objects :  {'motorcycle': 4, 'car': 14, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  559
# FOR FRAME  559
# Output count for unique objects :  {'motorcycle': 4, 'car': 14, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  560
# FOR FRAME  560
# Output count for unique objects :  {'motorcycle': 3, 'car': 12, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  561
# FOR FRAME  561
# Output count for unique objects :  {'motorcycle': 3, 'car': 15, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  562
# FOR FRAME  562
# Output count for unique objects :  {'motorcycle': 4, 'car': 12, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  563
# FOR FRAME  563
# Output count for unique objects :  {'motorcycle': 4, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  564
# FOR FRAME  564
# Output count for unique objects :  {'motorcycle': 3, 'car': 12, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  565
# FOR FRAME  565
# Output count for unique objects :  {'motorcycle': 3, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  566
# FOR FRAME  566
# Output count for unique objects :  {'motorcycle': 3, 'car': 15, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  567
# FOR FRAME  567
# Output count for unique objects :  {'bus': 1, 'motorcycle': 4, 'car': 13, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  568
# FOR FRAME  568
# Output count for unique objects :  {'motorcycle': 5, 'car': 13, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  569
# FOR FRAME  569
# Output count for unique objects :  {'motorcycle': 5, 'car': 12, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  570
# FOR FRAME  570
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  571
# FOR FRAME  571
# Output count for unique objects :  {'motorcycle': 3, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  572
# FOR FRAME  572
# Output count for unique objects :  {'bus': 1, 'motorcycle': 3, 'car': 11, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  573
# FOR FRAME  573
# Output count for unique objects :  {'motorcycle': 3, 'car': 11, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  574
# FOR FRAME  574
# Output count for unique objects :  {'motorcycle': 3, 'car': 11, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  575
# FOR FRAME  575
# Output count for unique objects :  {'motorcycle': 4, 'car': 11, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  576
# FOR FRAME  576
# Output count for unique objects :  {'motorcycle': 5, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  577
# FOR FRAME  577
# Output count for unique objects :  {'motorcycle': 2, 'car': 11, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  578
# FOR FRAME  578
# Output count for unique objects :  {'motorcycle': 3, 'car': 11, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  579
# FOR FRAME  579
# Output count for unique objects :  {'motorcycle': 4, 'car': 11, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  580
# FOR FRAME  580
# Output count for unique objects :  {'bus': 1, 'motorcycle': 2, 'car': 13, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  581
# FOR FRAME  581
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 9, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  582
# FOR FRAME  582
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'motorcycle': 1, 'car': 12, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  583
# FOR FRAME  583
# Output count for unique objects :  {'truck': 1, 'motorcycle': 2, 'car': 13, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  584
# FOR FRAME  584
# Output count for unique objects :  {'motorcycle': 2, 'car': 12, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  585
# FOR FRAME  585
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'motorcycle': 1, 'car': 15, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  586
# FOR FRAME  586
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'motorcycle': 2, 'car': 15, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  587
# FOR FRAME  587
# Output count for unique objects :  {'bus': 1, 'motorcycle': 3, 'car': 13, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  588
# FOR FRAME  588
# Output count for unique objects :  {'bus': 1, 'motorcycle': 3, 'car': 16, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  589
# FOR FRAME  589
# Output count for unique objects :  {'motorcycle': 2, 'car': 14, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  590
# FOR FRAME  590
# Output count for unique objects :  {'bus': 1, 'motorcycle': 3, 'car': 15, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  591
# FOR FRAME  591
# Output count for unique objects :  {'motorcycle': 1, 'car': 14, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  592
# FOR FRAME  592
# Output count for unique objects :  {'motorcycle': 2, 'car': 11, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  593
# FOR FRAME  593
# Output count for unique objects :  {'motorcycle': 1, 'car': 12, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  594
# FOR FRAME  594
# Output count for unique objects :  {'motorcycle': 3, 'car': 10, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  595
# FOR FRAME  595
# Output count for unique objects :  {'motorcycle': 1, 'car': 10, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  596
# FOR FRAME  596
# Output count for unique objects :  {'motorcycle': 2, 'car': 12, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  597
# FOR FRAME  597
# Output count for unique objects :  {'motorcycle': 1, 'car': 10, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  598
# FOR FRAME  598
# Output count for unique objects :  {'motorcycle': 3, 'car': 12, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  599
# FOR FRAME  599
# Output count for unique objects :  {'motorcycle': 4, 'car': 13, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  600

# %%
print('Finished...')
