# %% [markdown]
# # Object Detection Video
#
# ### Documentation:
# https://imageai.readthedocs.io/en/latest/
# https://imageai.readthedocs.io/en/latest/video/index.html
# https://towardsdatascience.com/object-detection-with-10-lines-of-code-d6cb4d86f606
# https://github.com/OlafenwaMoses/ImageAI/blob/master/imageai/Detection/VIDEO.md
#
# MRobalinho - 05-11-2018

# %% [markdown]
# -------------------------------------------------------
# #### In order to Install ImageAI see this page:
#
# https://imageai.readthedocs.io/en/latest/
#
# <br/>Installing ImageAI
# <br/>ImageAI requires that you have Python 3.5.1 or higher installed as well as some other Python libraries and frameworks. Before you install ImageAI, you must install the following dependencies.
# <br/>
# <br/>Download and install:
# <br/>Python 3.5.1 or higher, Download Python here: https://www.python.org/downloads/
# <br/>pip3 , Download PyPi here: https://pypi.org/project/pip/
# <br/>
# <br/>Use Command line CMD.exe as admnistrator
# <br/>
# <br/>Tensorflow 1.4.0 or higher  > pip3 install --upgrade tensorflow
# <br/>Numpy 1.13.1 or higher     	> pip3 install numpy
# <br/>SciPy .19.1 or higher		> pip3 install scipy
# <br/>OpenCV						> pip3 install opencv-python
# <br/>Pillow						> pip3 install pillow
# <br/>Matplotlib					> pip3 install matplotlib
# <br/>h5py						> pip3 install h5py
# <br/>Keras						> pip3 install keras
# <br/>Install ImageAI  			> pip3 install https://github.com/OlafenwaMoses/ImageAI/releases/download/2.0.2/imageai-2.0.2-py3-none-any.whl
#
# -------------------------

# %%
# Import packages
from imageai.Detection import VideoObjectDetection
import os
# Out:
# Using TensorFlow backend.

# %% [markdown]
# VideoObjectDetection class provides you function to detect objects in videos and live-feed from device cameras and IP cameras, using pre-trained models that was trained on the COCO dataset. The models supported are RetinaNet, YOLOv3 and TinyYOLOv3. This means you can detect and recognize 80 different kind of common everyday objects in any video. To get started, download any of the pre-trained model that you want to use via the links below.
#
# <br/>Download RetinaNet Model - resnet50_coco_best_v2.0.1.h5
# <br/>https://github.com/OlafenwaMoses/ImageAI/releases/tag/1.0/
# <br/>Download YOLOv3 Model - yolo.h5
# <br/>https://github.com/OlafenwaMoses/ImageAI/releases/tag/1.0/
# <br/>Download TinyYOLOv3 Model - yolo-tiny.h5
# <br/>https://github.com/OlafenwaMoses/ImageAI/releases/tag/1.0/

# %% [markdown]
# To obtain the video analysis, we need to do is specify a function, state the corresponding parameters it will be receiving and parse the function name into the per_frame_function, per_second_function, per_minute_function and video_complete_function parameters in the detection function.

# %% [markdown]
# For any function we parse into the <b> per_frame_function</b>, the function will be executed after every single video frame is processed and he following will be parsed into it:
# >> Frame Index : This is the position number of the frame inside the video (e.g 1 for first frame and 20 for twentieth frame).
#
# >> Output Array : This is an array of dictionaries. Each dictionary corresponds to each detected object in the image and it contains the "name", "percentage_probabaility" and "box_points"(x1,y1,x2,y2) values of the object.
#
# >> Output Count : This is a dictionary that has the name of each unique object detected as its keys and the number of instances of the objects detected as the values.

# %% [markdown]
# In the above result, the video was processed and saved in 10 frames per second (FPS). For any function you parse into the <b>per_second_function</b>, the function will be executed after every single second of the video that is processed and he following will be parsed into it:
# >> Second Index : This is the position number of the second inside the video (e.g 1 for first second and 20 for twentieth second).
#
# >> Output Array : This is an array of arrays, with each contained array and its position (array index + 1) corresponding to the equivalent frame in the last second of the video. Each contained array contains dictionaries. Each dictionary corresponds to each detected object in the image and it contains the "name", "percentage_probabaility" and "box_points"(x1,y1,x2,y2) values of the object.
#
# >> Count arrays : This is an array of dictionaries. Each dictionary and its position (array index + 1) corresponds to the equivalent frame in the last second of he video. Each dictionary has the name of each unique object detected as its keys and the number of instances of the objects detected as the values.
#
# >> Average Output Count : This is a dictionary that has the name of each unique object detected in the last second as its keys and the average number of instances of the objects detected across the number of frames as the values.

# %%
def forFrame(frame_number, output_array, output_count, detected_copy):
    print("FOR FRAME " , frame_number)
#    print("Output for each object : ", output_array)
    print("Output count for unique objects : ", output_count)
    print("------------END OF A FRAME --------------")

def forSeconds(second_number, output_arrays, count_arrays, average_output_count, detected_copy):
    print("SECOND : ", second_number)
#    print("Array for the outputs of each frame ", output_arrays)
    print("Array for output count for unique objects in each frame : ", count_arrays)
    print("Output average count for unique objects in the last second: ", average_output_count)
    print("------------END OF A SECOND --------------")

def forMinute(minute_number, output_arrays, count_arrays, average_output_count, detected_copy):
    print("MINUTE : ", minute_number)
#    print("Array for the outputs of each frame ", output_arrays)
    print("Array for output count for unique objects in each frame : ", count_arrays)
    print("Output average count for unique objects in the last minute: ", average_output_count)
    print("------------END OF A MINUTE --------------")

# %%
# Path to execute
yolo_path = 'TinyYOLOv3_Model/'
video_path = 'Video/'
execution_path = os.getcwd()
execution_path
# Out:
# 'C:\\Users\\Lenovo\\ML\\Object-Detection-Video'

# %%
video_path
# Out:
# 'Video/'

# %%
# Video to Use
use_video = "traffic-mini.mp4"

# %%
# Model to Use
use_model = "yolo-tiny.h5"

analisys_video = "detected_" + use_video

detector = VideoObjectDetection()

# Iniciate model
#detector.setModelTypeAsYOLOv3()      # To YOLOv3 model
#detector.setModelTypeAsRetinaNet()   # To Retinanet model
detector.setModelTypeAsTinyYOLOv3()   # To TinyYOLOv3 model

detector.setModelPath( os.path.join(yolo_path , use_model))
detector.loadModel()

vid_path = detector.detectObjectsFromVideo(input_file_path=os.path.join( video_path, use_video),
                                           output_file_path=os.path.join(video_path, analisys_video),
                                           frames_per_second=20,
                                 #          per_second_function = forSeconds,
                                           per_frame_function = forFrame,
                                 #          per_minute_function= forMinute,
                                           minimum_percentage_probability=30,
                                           log_progress=True,
                                           return_detected_frame=True)
                                           
 
print(vid_path)
# Out:
# Processing Frame :  1
# FOR FRAME  1
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  2
# FOR FRAME  2
# Output count for unique objects :  {'motorcycle': 1, 'car': 3, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  3
# FOR FRAME  3
# Output count for unique objects :  {'motorcycle': 1, 'car': 5, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  4
# FOR FRAME  4
# Output count for unique objects :  {'motorcycle': 1, 'car': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  5
# FOR FRAME  5
# Output count for unique objects :  {'motorcycle': 1, 'car': 3, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  6
# FOR FRAME  6
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  7
# FOR FRAME  7
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  8
# FOR FRAME  8
# Output count for unique objects :  {'motorcycle': 1, 'car': 5, 'person': 8}
# ------------END OF A FRAME --------------
# Processing Frame :  9
# FOR FRAME  9
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 7}
# ------------END OF A FRAME --------------
# Processing Frame :  10
# FOR FRAME  10
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  11
# FOR FRAME  11
# Output count for unique objects :  {'motorcycle': 1, 'car': 5, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  12
# FOR FRAME  12
# Output count for unique objects :  {'motorcycle': 1, 'car': 5, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  13
# FOR FRAME  13
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  14
# FOR FRAME  14
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  15
# FOR FRAME  15
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  16
# FOR FRAME  16
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  17
# FOR FRAME  17
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  18
# FOR FRAME  18
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  19
# FOR FRAME  19
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  20
# FOR FRAME  20
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 4, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  21
# FOR FRAME  21
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 3, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  22
# FOR FRAME  22
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 2, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  23
# FOR FRAME  23
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 2, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  24
# FOR FRAME  24
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 2, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  25
# FOR FRAME  25
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 3, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  26
# FOR FRAME  26
# Output count for unique objects :  {'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  27
# FOR FRAME  27
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  28
# FOR FRAME  28
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  29
# FOR FRAME  29
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  30
# FOR FRAME  30
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  31
# FOR FRAME  31
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 4, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  32
# FOR FRAME  32
# Output count for unique objects :  {'bus': 1, 'motorcycle': 1, 'car': 4, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  33
# FOR FRAME  33
# Output count for unique objects :  {'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  34
# FOR FRAME  34
# Output count for unique objects :  {'car': 4, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  35
# FOR FRAME  35
# Output count for unique objects :  {'car': 3, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  36
# FOR FRAME  36
# Output count for unique objects :  {'car': 3, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  37
# FOR FRAME  37
# Output count for unique objects :  {'car': 3, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  38
# FOR FRAME  38
# Output count for unique objects :  {'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  39
# FOR FRAME  39
# Output count for unique objects :  {'car': 3, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  40
# FOR FRAME  40
# Output count for unique objects :  {'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  41
# FOR FRAME  41
# Output count for unique objects :  {'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  42
# FOR FRAME  42
# Output count for unique objects :  {'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  43
# FOR FRAME  43
# Output count for unique objects :  {'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  44
# FOR FRAME  44
# Output count for unique objects :  {'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  45
# FOR FRAME  45
# Output count for unique objects :  {'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  46
# FOR FRAME  46
# Output count for unique objects :  {'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  47
# FOR FRAME  47
# Output count for unique objects :  {'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  48
# FOR FRAME  48
# Output count for unique objects :  {'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  49
# FOR FRAME  49
# Output count for unique objects :  {'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  50
# FOR FRAME  50
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  51
# FOR FRAME  51
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  52
# FOR FRAME  52
# Output count for unique objects :  {'bus': 1, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  53
# FOR FRAME  53
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  54
# FOR FRAME  54
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  55
# FOR FRAME  55
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  56
# FOR FRAME  56
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  57
# FOR FRAME  57
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  58
# FOR FRAME  58
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  59
# FOR FRAME  59
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  60
# FOR FRAME  60
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  61
# FOR FRAME  61
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  62
# FOR FRAME  62
# Output count for unique objects :  {'bus': 1, 'car': 3, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  63
# FOR FRAME  63
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  64
# FOR FRAME  64
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  65
# FOR FRAME  65
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  66
# FOR FRAME  66
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  67
# FOR FRAME  67
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  68
# FOR FRAME  68
# Output count for unique objects :  {'bus': 1, 'car': 3, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  69
# FOR FRAME  69
# Output count for unique objects :  {'bus': 1, 'car': 3, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  70
# FOR FRAME  70
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  71
# FOR FRAME  71
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  72
# FOR FRAME  72
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  73
# FOR FRAME  73
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  74
# FOR FRAME  74
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  75
# FOR FRAME  75
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  76
# FOR FRAME  76
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  77
# FOR FRAME  77
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  78
# FOR FRAME  78
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  79
# FOR FRAME  79
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  80
# FOR FRAME  80
# Output count for unique objects :  {'bus': 2, 'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  81
# FOR FRAME  81
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  82
# FOR FRAME  82
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  83
# FOR FRAME  83
# Output count for unique objects :  {'bus': 2, 'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  84
# FOR FRAME  84
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  85
# FOR FRAME  85
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  86
# FOR FRAME  86
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  87
# FOR FRAME  87
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  88
# FOR FRAME  88
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  89
# FOR FRAME  89
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  90
# FOR FRAME  90
# Output count for unique objects :  {'bus': 1, 'car': 5, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  91
# FOR FRAME  91
# Output count for unique objects :  {'bus': 1, 'car': 5, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  92
# FOR FRAME  92
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  93
# FOR FRAME  93
# Output count for unique objects :  {'bus': 1, 'car': 3, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  94
# FOR FRAME  94
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  95
# FOR FRAME  95
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  96
# FOR FRAME  96
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  97
# FOR FRAME  97
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  98
# FOR FRAME  98
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  99
# FOR FRAME  99
# Output count for unique objects :  {'chair': 1, 'bus': 1, 'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  100
# FOR FRAME  100
# Output count for unique objects :  {'bus': 2, 'car': 3, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  101
# FOR FRAME  101
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  102
# FOR FRAME  102
# Output count for unique objects :  {'bus': 2, 'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  103
# FOR FRAME  103
# Output count for unique objects :  {'bus': 2, 'car': 3, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  104
# FOR FRAME  104
# Output count for unique objects :  {'bus': 2, 'car': 4, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  105
# FOR FRAME  105
# Output count for unique objects :  {'bus': 1, 'car': 3, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  106
# FOR FRAME  106
# Output count for unique objects :  {'bus': 2, 'car': 5, 'bicycle': 2, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  107
# FOR FRAME  107
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  108
# FOR FRAME  108
# Output count for unique objects :  {'bus': 2, 'car': 3, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  109
# FOR FRAME  109
# Output count for unique objects :  {'bus': 2, 'car': 3, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  110
# FOR FRAME  110
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 3, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  111
# FOR FRAME  111
# Output count for unique objects :  {'bus': 2, 'car': 3, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  112
# FOR FRAME  112
# Output count for unique objects :  {'bus': 2, 'car': 2, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  113
# FOR FRAME  113
# Output count for unique objects :  {'bus': 2, 'car': 3, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  114
# FOR FRAME  114
# Output count for unique objects :  {'bus': 2, 'car': 5, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  115
# FOR FRAME  115
# Output count for unique objects :  {'bus': 2, 'car': 5, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  116
# FOR FRAME  116
# Output count for unique objects :  {'bus': 2, 'car': 3, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  117
# FOR FRAME  117
# Output count for unique objects :  {'bus': 1, 'car': 6, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  118
# FOR FRAME  118
# Output count for unique objects :  {'bus': 2, 'car': 5, 'bicycle': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  119
# FOR FRAME  119
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  120
# FOR FRAME  120
# Output count for unique objects :  {'bus': 2, 'car': 4, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  121
# FOR FRAME  121
# Output count for unique objects :  {'bus': 2, 'car': 6, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  122
# FOR FRAME  122
# Output count for unique objects :  {'bus': 2, 'car': 3, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  123
# FOR FRAME  123
# Output count for unique objects :  {'bus': 2, 'car': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  124
# FOR FRAME  124
# Output count for unique objects :  {'bus': 2, 'car': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  125
# FOR FRAME  125
# Output count for unique objects :  {'bus': 2, 'car': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  126
# FOR FRAME  126
# Output count for unique objects :  {'bus': 2, 'car': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  127
# FOR FRAME  127
# Output count for unique objects :  {'bus': 2, 'car': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  128
# FOR FRAME  128
# Output count for unique objects :  {'bus': 2, 'car': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  129
# FOR FRAME  129
# Output count for unique objects :  {'bus': 2, 'car': 2, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  130
# FOR FRAME  130
# Output count for unique objects :  {'bus': 2, 'car': 5, 'bicycle': 2, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  131
# FOR FRAME  131
# Output count for unique objects :  {'bus': 1, 'car': 3, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  132
# FOR FRAME  132
# Output count for unique objects :  {'bus': 2, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  133
# FOR FRAME  133
# Output count for unique objects :  {'bus': 2, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  134
# FOR FRAME  134
# Output count for unique objects :  {'bus': 2, 'car': 6, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  135
# FOR FRAME  135
# Output count for unique objects :  {'bus': 2, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  136
# FOR FRAME  136
# Output count for unique objects :  {'bus': 1, 'car': 4, 'bicycle': 1, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  137
# FOR FRAME  137
# Output count for unique objects :  {'bus': 2, 'car': 4, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  138
# FOR FRAME  138
# Output count for unique objects :  {'bus': 1, 'car': 3, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  139
# FOR FRAME  139
# Output count for unique objects :  {'bus': 1, 'car': 3, 'bicycle': 2, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  140
# FOR FRAME  140
# Output count for unique objects :  {'bus': 2, 'car': 4, 'bicycle': 1, 'person': 6}
# ------------END OF A FRAME --------------
# Processing Frame :  141
# FOR FRAME  141
# Output count for unique objects :  {'bus': 1, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  142
# FOR FRAME  142
# Output count for unique objects :  {'bus': 2, 'car': 4, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  143
# FOR FRAME  143
# Output count for unique objects :  {'bus': 3, 'car': 4, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  144
# FOR FRAME  144
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  145
# FOR FRAME  145
# Output count for unique objects :  {'bus': 2, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  146
# FOR FRAME  146
# Output count for unique objects :  {'bus': 1, 'car': 4, 'person': 5}
# ------------END OF A FRAME --------------
# Processing Frame :  147
# FOR FRAME  147
# Output count for unique objects :  {'bus': 1, 'car': 6, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  148
# FOR FRAME  148
# Output count for unique objects :  {'bus': 1, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  149
# FOR FRAME  149
# Output count for unique objects :  {'bus': 1, 'car': 5, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  150
# FOR FRAME  150
# Output count for unique objects :  {'bus': 1, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  151
# FOR FRAME  151
# Output count for unique objects :  {'bus': 1, 'car': 7, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  152
# FOR FRAME  152
# Output count for unique objects :  {'bus': 1, 'car': 8, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  153
# FOR FRAME  153
# Output count for unique objects :  {'bus': 1, 'car': 8, 'bicycle': 1, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  154
# FOR FRAME  154
# Output count for unique objects :  {'car': 8, 'bicycle': 2, 'person': 4}
# ------------END OF A FRAME --------------
# Processing Frame :  155
# FOR FRAME  155
# Output count for unique objects :  {'car': 8, 'bicycle': 2, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  156
# FOR FRAME  156
# Output count for unique objects :  {'bus': 1, 'car': 9, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  157
# FOR FRAME  157
# Output count for unique objects :  {'bus': 1, 'car': 9, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  158
# FOR FRAME  158
# Output count for unique objects :  {'car': 9, 'bicycle': 1, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  159
# FOR FRAME  159
# Output count for unique objects :  {'car': 6, 'bicycle': 1, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  160
# FOR FRAME  160
# Output count for unique objects :  {'car': 9, 'person': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  161
# FOR FRAME  161
# Output count for unique objects :  {'car': 9, 'bicycle': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  162
# FOR FRAME  162
# Output count for unique objects :  {'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  163
# FOR FRAME  163
# Output count for unique objects :  {'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  164
# FOR FRAME  164
# Output count for unique objects :  {'truck': 1, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  165
# FOR FRAME  165
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  166
# FOR FRAME  166
# Output count for unique objects :  {'truck': 1, 'car': 9, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  167
# FOR FRAME  167
# Output count for unique objects :  {'truck': 1, 'car': 10, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  168
# FOR FRAME  168
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  169
# FOR FRAME  169
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  170
# FOR FRAME  170
# Output count for unique objects :  {'truck': 1, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  171
# FOR FRAME  171
# Output count for unique objects :  {'truck': 1, 'car': 8, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  172
# FOR FRAME  172
# Output count for unique objects :  {'truck': 1, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  173
# FOR FRAME  173
# Output count for unique objects :  {'truck': 1, 'car': 5, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  174
# FOR FRAME  174
# Output count for unique objects :  {'truck': 1, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  175
# FOR FRAME  175
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  176
# FOR FRAME  176
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  177
# FOR FRAME  177
# Output count for unique objects :  {'truck': 1, 'bus': 1, 'car': 7, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  178
# FOR FRAME  178
# Output count for unique objects :  {'truck': 1, 'bus': 2, 'car': 5, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  179
# FOR FRAME  179
# Output count for unique objects :  {'sink': 1, 'truck': 1, 'bus': 1, 'car': 6, 'person': 2}
# ------------END OF A FRAME --------------
# Video/detected_traffic-mini.mp4.avi

# %%
print('Finished...')
# Out:
# Finished...
